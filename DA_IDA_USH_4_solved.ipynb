# %% [markdown]
# # Module: Introduction to Data Analytics
# ## Sprint: Utilising Spreadsheets for Data Analytics
# ## Part 4: Spreadsheets Hands-on Practice
#
# * Google Spreadsheets solution can be found [here](https://docs.google.com/spreadsheets/d/1rvXqBlOBqYnUt9fQOCEzMboRyN0xW_-SglH1NBp8H2c/edit#gid=2061326352)
# * Microsoft Spreadsheets solution can be found [here](https://docs.google.com/spreadsheets/d/16H5016saqKtNfvBgadcq4WW5JFhul1t9/edit?rtpof=true)
